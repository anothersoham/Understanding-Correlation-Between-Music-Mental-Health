# %%
#Loading the resource libraries crucial for the analysis
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from unittest.mock import patch

# %%
#Loading the Dataset 1 and reinforcing the first row of the dataset as the index

cs = pd.read_csv('share-with-mental-and-substance-disorders.csv',index_col=0)

# %%
#Calling the dataset to check the structure
cs
# Out:
#             Code  Year  \
# Entity
# Afghanistan  AFG  1990
# Afghanistan  AFG  1991
# Afghanistan  AFG  1992
# Afghanistan  AFG  1993
# Afghanistan  AFG  1994
# ...          ...   ...
# Zimbabwe     ZWE  2015
# Zimbabwe     ZWE  2016
# Zimbabwe     ZWE  2017
# Zimbabwe     ZWE  2018
# Zimbabwe     ZWE  2019
#
#              Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)
# Entity
# Afghanistan                                              16.66
# Afghanistan                                              16.77
# Afghanistan                                              16.87
# Afghanistan                                              16.99
# Afghanistan                                              17.11
# ...                                                        ...
# Zimbabwe                                                 11.16
# Zimbabwe                                                 11.16
# Zimbabwe                                                 11.17
# ...

# %%
#Reaffirming the shape of the entire dataset
cs.shape
# Out:
# (6752, 3)

# %%
#Figuring out the data types
cs.dtypes
# Out:
# Code                                                                            object
# Year                                                                             int64
# Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)    float64
# dtype: object

# %%
#Loading the information summary 
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6752 entries, Afghanistan to Zimbabwe
# Data columns (total 3 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Code                                                                         6062 non-null   object
#  1   Year                                                                         6752 non-null   int64
#  2   Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)  6752 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 211.0+ KB

# %%
#Specifing the rows required for the analysis
specific_rows = [0,6243,6244,6245,6246,6247,6248,6249,6250,6251,6252,6253,6254,6255,6256,6257,6258,6259,6260,6261,6262,6263,6264,6265,6266,6267,6268,6269,6270,6271,6272]

# %%
#Calling the specified rows from the dataset
cs1 = pd.read_csv('share-with-mental-and-substance-disorders.csv', skiprows = lambda x: x not in specific_rows)

# %%
#Calling the dataset to check the revised structure
cs1
# Out:
#            Entity Code  Year  \
# 0   United States  USA  1990
# 1   United States  USA  1991
# 2   United States  USA  1992
# 3   United States  USA  1993
# 4   United States  USA  1994
# 5   United States  USA  1995
# 6   United States  USA  1996
# 7   United States  USA  1997
# 8   United States  USA  1998
# 9   United States  USA  1999
# 10  United States  USA  2000
# 11  United States  USA  2001
# 12  United States  USA  2002
# 13  United States  USA  2003
# 14  United States  USA  2004
# 15  United States  USA  2005
# 16  United States  USA  2006
# 17  United States  USA  2007
# 18  United States  USA  2008
# 19  United States  USA  2009
# 20  United States  USA  2010
# 21  United States  USA  2011
# 22  United States  USA  2012
# 23  United States  USA  2013
# 24  United States  USA  2014
# 25  United States  USA  2015
# 26  United States  USA  2016
# 27  United States  USA  2017
# 28  United States  USA  2018
# 29  United States  USA  2019
#
# ...

# %%
#Renaming the columns for tidier data and precise understanding
cs1.rename(columns={"Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)": "Mental Health Cases (Percentage)"}, inplace=True)

# %%
#Calling the dataset to check the applied edit
cs1
# Out:
#            Entity Code  Year  Mental Health Cases (Percentage)
# 0   United States  USA  1990                             15.56
# 1   United States  USA  1991                             15.75
# 2   United States  USA  1992                             15.95
# 3   United States  USA  1993                             16.14
# 4   United States  USA  1994                             16.31
# 5   United States  USA  1995                             16.44
# 6   United States  USA  1996                             16.68
# 7   United States  USA  1997                             17.07
# 8   United States  USA  1998                             17.50
# 9   United States  USA  1999                             17.84
# 10  United States  USA  2000                             18.00
# 11  United States  USA  2001                             17.97
# 12  United States  USA  2002                             17.88
# 13  United States  USA  2003                             17.74
# ...

# %%
#Reindexing the columns
cs1.reindex(columns=['Entity', 'Code', 'Year', 'Mental Health Cases (Percentage)'])
# Out:
#            Entity Code  Year  Mental Health Cases (Percentage)
# 0   United States  USA  1990                             15.56
# 1   United States  USA  1991                             15.75
# 2   United States  USA  1992                             15.95
# 3   United States  USA  1993                             16.14
# 4   United States  USA  1994                             16.31
# 5   United States  USA  1995                             16.44
# 6   United States  USA  1996                             16.68
# 7   United States  USA  1997                             17.07
# 8   United States  USA  1998                             17.50
# 9   United States  USA  1999                             17.84
# 10  United States  USA  2000                             18.00
# 11  United States  USA  2001                             17.97
# 12  United States  USA  2002                             17.88
# 13  United States  USA  2003                             17.74
# ...

# %%
#Specifing the required columns for visualisation
cs2= cs1[['Year', 'Mental Health Cases (Percentage)']]

# %%
#Calling the dataset to check the revised structure
cs2
# Out:
#     Year  Mental Health Cases (Percentage)
# 0   1990                             15.56
# 1   1991                             15.75
# 2   1992                             15.95
# 3   1993                             16.14
# 4   1994                             16.31
# 5   1995                             16.44
# 6   1996                             16.68
# 7   1997                             17.07
# 8   1998                             17.50
# 9   1999                             17.84
# 10  2000                             18.00
# 11  2001                             17.97
# 12  2002                             17.88
# 13  2003                             17.74
# 14  2004                             17.61
# 15  2005                             17.52
# 16  2006                             17.47
# 17  2007                             17.45
# 18  2008                             17.43
# 19  2009                             17.41
# 20  2010                             17.35
# ...

# %%
#Figure 9:Prevalence of Mental Health Disorders in US (1990-2019)
#Using the Seaborn to plot a linegraph of the percentage of mental illness between 1990 and 2019 in the US 

plt.figure(figsize=(12, 7), 
           dpi = 1200) 
 
ax1= sns.lineplot(data= cs2, x="Year", y= "Mental Health Cases (Percentage)", color="orange", lw=3.5)
ax1.set_title('Figure 9: Prevalence of Mental Health Disorders in the US (1990-2019)',fontsize=16)
plt.tick_params(axis = 'x', labelsize = 12)
plt.tick_params(axis = 'y', labelsize = 12)
plt.legend(labels=["The Percentage of Mental Health Cases"], title= "Data")
plt.show()
